# %%
from neural_network import NeuralNetwork
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
NNs = []
for i in range(0,10):
    NNs.append(NeuralNetwork())

# %%
for i in range(0,10):
    NNs[i].load_data()

# %%
for i in range(0,10):
    print(f"----- TRAINING NN {i+1} -----")
    NNs[i].train()
# Out:
# ----- TRAINING NN 1 -----
# Epoch 1/5 | Train Loss: 0.5264 | Train Acc: 73.99% | Val Loss: 0.5283
# Epoch 2/5 | Train Loss: 0.5119 | Train Acc: 74.89% | Val Loss: 0.5254
# Epoch 3/5 | Train Loss: 0.5101 | Train Acc: 75.09% | Val Loss: 0.5264
# Epoch 4/5 | Train Loss: 0.5093 | Train Acc: 75.08% | Val Loss: 0.5242
# Epoch 5/5 | Train Loss: 0.5086 | Train Acc: 75.04% | Val Loss: 0.5247
# ----- TRAINING NN 2 -----
# Epoch 1/5 | Train Loss: 0.5336 | Train Acc: 73.32% | Val Loss: 0.5166
# Epoch 2/5 | Train Loss: 0.5150 | Train Acc: 74.98% | Val Loss: 0.5149
# Epoch 3/5 | Train Loss: 0.5124 | Train Acc: 75.04% | Val Loss: 0.5164
# Epoch 4/5 | Train Loss: 0.5110 | Train Acc: 75.27% | Val Loss: 0.5153
# Epoch 5/5 | Train Loss: 0.5103 | Train Acc: 75.26% | Val Loss: 0.5139
# ----- TRAINING NN 3 -----
# Epoch 1/5 | Train Loss: 0.5269 | Train Acc: 74.11% | Val Loss: 0.5196
# Epoch 2/5 | Train Loss: 0.5119 | Train Acc: 75.03% | Val Loss: 0.5176
# Epoch 3/5 | Train Loss: 0.5100 | Train Acc: 75.23% | Val Loss: 0.5176
# Epoch 4/5 | Train Loss: 0.5090 | Train Acc: 75.31% | Val Loss: 0.5178
# Epoch 5/5 | Train Loss: 0.5080 | Train Acc: 75.29% | Val Loss: 0.5170
# ----- TRAINING NN 4 -----
# Epoch 1/5 | Train Loss: 0.5293 | Train Acc: 73.92% | Val Loss: 0.5099
# Epoch 2/5 | Train Loss: 0.5160 | Train Acc: 74.62% | Val Loss: 0.5088
# Epoch 3/5 | Train Loss: 0.5131 | Train Acc: 74.91% | Val Loss: 0.5058
# Epoch 4/5 | Train Loss: 0.5115 | Train Acc: 75.09% | Val Loss: 0.5056
# Epoch 5/5 | Train Loss: 0.5104 | Train Acc: 75.05% | Val Loss: 0.5054
# ----- TRAINING NN 5 -----
# Epoch 1/5 | Train Loss: 0.5265 | Train Acc: 73.89% | Val Loss: 0.5155
# Epoch 2/5 | Train Loss: 0.5140 | Train Acc: 74.82% | Val Loss: 0.5114
# Epoch 3/5 | Train Loss: 0.5111 | Train Acc: 75.06% | Val Loss: 0.5106
# Epoch 4/5 | Train Loss: 0.5097 | Train Acc: 75.15% | Val Loss: 0.5089
# Epoch 5/5 | Train Loss: 0.5086 | Train Acc: 75.12% | Val Loss: 0.5071
# ----- TRAINING NN 6 -----
# Epoch 1/5 | Train Loss: 0.5293 | Train Acc: 73.65% | Val Loss: 0.5227
# Epoch 2/5 | Train Loss: 0.5129 | Train Acc: 74.82% | Val Loss: 0.5221
# Epoch 3/5 | Train Loss: 0.5109 | Train Acc: 75.13% | Val Loss: 0.5200
# Epoch 4/5 | Train Loss: 0.5093 | Train Acc: 75.19% | Val Loss: 0.5225
# Epoch 5/5 | Train Loss: 0.5085 | Train Acc: 75.14% | Val Loss: 0.5201
# ----- TRAINING NN 7 -----
# Epoch 1/5 | Train Loss: 0.5309 | Train Acc: 73.73% | Val Loss: 0.5132
# Epoch 2/5 | Train Loss: 0.5155 | Train Acc: 74.71% | Val Loss: 0.5087
# Epoch 3/5 | Train Loss: 0.5131 | Train Acc: 74.85% | Val Loss: 0.5083
# Epoch 4/5 | Train Loss: 0.5119 | Train Acc: 74.91% | Val Loss: 0.5087
# Epoch 5/5 | Train Loss: 0.5113 | Train Acc: 74.97% | Val Loss: 0.5077
# ----- TRAINING NN 8 -----
# Epoch 1/5 | Train Loss: 0.5299 | Train Acc: 73.70% | Val Loss: 0.5208
# Epoch 2/5 | Train Loss: 0.5130 | Train Acc: 74.96% | Val Loss: 0.5186
# Epoch 3/5 | Train Loss: 0.5108 | Train Acc: 75.19% | Val Loss: 0.5174
# Epoch 4/5 | Train Loss: 0.5096 | Train Acc: 75.13% | Val Loss: 0.5185
# Epoch 5/5 | Train Loss: 0.5088 | Train Acc: 75.17% | Val Loss: 0.5219
# ----- TRAINING NN 9 -----
# Epoch 1/5 | Train Loss: 0.5244 | Train Acc: 74.07% | Val Loss: 0.5251
# Epoch 2/5 | Train Loss: 0.5098 | Train Acc: 75.11% | Val Loss: 0.5233
# Epoch 3/5 | Train Loss: 0.5069 | Train Acc: 75.32% | Val Loss: 0.5197
# Epoch 4/5 | Train Loss: 0.5060 | Train Acc: 75.32% | Val Loss: 0.5215
# Epoch 5/5 | Train Loss: 0.5050 | Train Acc: 75.52% | Val Loss: 0.5214
# ----- TRAINING NN 10 -----
# Epoch 1/5 | Train Loss: 0.5289 | Train Acc: 73.86% | Val Loss: 0.5141
# Epoch 2/5 | Train Loss: 0.5146 | Train Acc: 74.72% | Val Loss: 0.5132
# Epoch 3/5 | Train Loss: 0.5122 | Train Acc: 74.79% | Val Loss: 0.5111
# Epoch 4/5 | Train Loss: 0.5111 | Train Acc: 74.92% | Val Loss: 0.5118
# Epoch 5/5 | Train Loss: 0.5097 | Train Acc: 75.10% | Val Loss: 0.5110

# %%
results = []
for i in range(0,10):
    o1, o2, o3, o4 = NNs[i].evaluate()
    results_tuple = (o1,o2,o3,o4)
    results.append(results_tuple)
# Out:
# ================================================================================
# EVALUATION RESULTS ON TEST SET
# ================================================================================
#
# ROC-AUC Score: 0.8243
#
#  Threshold  Accuracy  Precision   Recall  F1-Score  Specificity   TP   TN   FP   FN
#        0.3  0.730418   0.681285 0.931075  0.786831     0.500150 7146 3345 3343  529
#        0.4  0.746293   0.713439 0.877785  0.787125     0.595395 6737 3982 2706  938
#        0.5  0.749774   0.743003 0.812899  0.776381     0.677333 6239 4530 2158 1436
#        0.6  0.741767   0.782398 0.715831  0.747636     0.771531 5494 5160 1528 2181
#        0.7  0.694911   0.822274 0.547362  0.657228     0.864234 4201 5780  908 3474
# ================================================================================
#
#
# ================================================================================
# EVALUATION RESULTS ON TEST SET
# ================================================================================
#
# ROC-AUC Score: 0.
#
#  Threshold  Accuracy  Precision   Recall  F1-Score  Specificity   TP   TN   FP   FN
#        0.3  0.699366   0.645765 0.955078  0.770539     0.412729 7250 2795 3977  341
#        0.4  0.726102   0.677542 0.919246  0.780101     0.509598 6978 3451 3321  613
#        0.5  0.741558   0.709381 0.865630  0.779756     0.602481 6571 4080 2692 1020
#        0.6  0.745179   0.748514 0.779871  0.763871     0.706291 5920 4783 1989 1671
#        0.7  0.716146   0.800342 0.616783  0.696674     0.827525 4682 5604 1168 2909
# ================================================================================
#
#
# ================================================================================
# EVALUATION RESULTS ON TEST SET
# ================================================================================
#
# ROC-AUC Score: 0.8115
#
#  Threshold  Accuracy  Precision   Recall  F1-Score  Specificity   TP   TN   FP   FN
#        0.3  0.720393   0.673674 0.930154  0.781406     0.476828 7178 3169 3477  539
#        0.4  0.740375   0.706247 0.884800  0.785505     0.572675 6828 3806 2840  889
#        0.5  0.743577   0.735576 0.816120  0.773758     0.659344 6298 4382 2264 1419
#        0.6  0.730906   0.767872 0.715433  0.740726     0.748872 5521 4977 1669 2196
#        0.7  0.689619   0.803728 0.558766  0.659226     0.841559 4312 5593 1053 3405
# ================================================================================
#
#
# ================================================================================
# EVALUATION RESULTS ON TEST SET
# ================================================================================
#
# ROC-AUC Score: 0.8196
#
#  Threshold  Accuracy  Precision   Recall  F1-Score  Specificity   TP   TN   FP   FN
#        0.3  0.724013   0.675928 0.932078  0.783601     0.483566 7177 3222 3441  523
#        0.4  0.739748   0.706011 0.881688  0.784130     0.575717 6789 3836 2827  911
#        0.5  0.749704   0.741045 0.819481  0.778292     0.669068 6310 4458 2205 1390
#        0.6  0.737381   0.774072 0.720390  0.746267     0.757016 5547 5044 1619 2153
#        0.7  0.698322   0.813326 0.567532  0.668554     0.849467 4370 5660 1003 3330
# ================================================================================

# %%
for i in range(0,10):
    display(results[i][0][["Threshold","F1-Score"]].sort_values(by="F1-Score",ascending=False))
# Out:
#    Threshold  F1-Score
# 1        0.4  0.787125
# 0        0.3  0.786831
# 2        0.5  0.776381
# 3        0.6  0.747636
# 4        0.7  0.657228
#    Threshold  F1-Score
# 1        0.4  0.785502
# 0        0.3  0.781447
# 2        0.5  0.776951
# 3        0.6  0.749916
# 4        0.7  0.680783
#    Threshold  F1-Score
# 1        0.4  0.783148
# 0        0.3  0.780313
# 2        0.5  0.775045
# 3        0.6  0.744895
# 4        0.7  0.664359
#    Threshold  F1-Score
# 1        0.4  0.779929
# 0        0.3  0.778447
# 2        0.5  0.769192
# 3        0.6  0.737483
# 4        0.7  0.656555
#    Threshold  F1-Score
# 1        0.4  0.780358
# 0        0.3  0.778483
# 2        0.5  0.770447
# 3        0.6  0.742807
# 4        0.7  0.659602
#    Threshold  F1-Score
# 1        0.4  0.786586
# 0        0.3  0.780893
# 2        0.5  0.777792
# 3        0.6  0.745221
# 4        0.7  0.674263
#    Threshold  F1-Score
# 1        0.4  0.788437
# 0        0.3  0.784079
# 2        0.5  0.779772
# 3        0.6  0.748754
# 4        0.7  0.668816
#    Threshold  F1-Score
# 1        0.4  0.780101
# 2        0.5  0.779756
# 0        0.3  0.770539
# 3        0.6  0.763871
# 4        0.7  0.696674
#    Threshold  F1-Score
# 1        0.4  0.785505
# 0        0.3  0.781406
# 2        0.5  0.773758
# 3        0.6  0.740726
# 4        0.7  0.659226
#    Threshold  F1-Score
# 1        0.4  0.784130
# 0        0.3  0.783601
# 2        0.5  0.778292
# 3        0.6  0.746267
# 4        0.7  0.668554

# %%
for i in range(0,10):
    result = results[i]
    NNs[i].plot_threshold_analysis(result[0],result[1],result[2])
