# %%
from neural_network import NeuralNetwork

# %%
nn = NeuralNetwork()

# %%
nn.load_data()

# %%
nn.train(20,0.001)
# Out:
# Epoch 1/20 | Train Loss: 0.5284 | Train Acc: 74.23% | Val Loss: 0.5188
# Epoch 2/20 | Train Loss: 0.5151 | Train Acc: 74.87% | Val Loss: 0.5151
# Epoch 3/20 | Train Loss: 0.5128 | Train Acc: 74.97% | Val Loss: 0.5146
# Epoch 4/20 | Train Loss: 0.5119 | Train Acc: 75.00% | Val Loss: 0.5129
# Epoch 5/20 | Train Loss: 0.5111 | Train Acc: 75.01% | Val Loss: 0.5124
# Epoch 6/20 | Train Loss: 0.5103 | Train Acc: 75.12% | Val Loss: 0.5115
# Epoch 7/20 | Train Loss: 0.5097 | Train Acc: 75.20% | Val Loss: 0.5128
# Epoch 8/20 | Train Loss: 0.5092 | Train Acc: 75.19% | Val Loss: 0.5118
# Epoch 9/20 | Train Loss: 0.5086 | Train Acc: 75.21% | Val Loss: 0.5130
# Epoch 10/20 | Train Loss: 0.5080 | Train Acc: 75.15% | Val Loss: 0.5137
# Epoch 11/20 | Train Loss: 0.5080 | Train Acc: 75.26% | Val Loss: 0.5143
# Early stopping triggered.

# %%
nn.evaluate()
# Out:
# ----- TEST METRICS -----
# Accuracy : 0.7483116340597368
# Precision: 0.7547495682210709
# Recall   : 0.7899289864428664
# F1 Score : 0.7719386789477004
